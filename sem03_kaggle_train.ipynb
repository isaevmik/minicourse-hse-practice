# %% [markdown]
# ## 1. Создание предсказательной модели и оценивание её качества.

# %% [markdown]
# Считаем данные из скачанной открытой гугл-папки

# %%
import os
import pandas as pd
path = r'C:\Users\Mikhail\Desktop\PracticeKaggle\d2' 
data = {}

Data = []
Target = []

i=0
for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=';')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass

for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=',')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-90287aaa6ffb> in <module>
#       8
#       9 i=0
# ---> 10 for dir_entry in sorted(os.listdir(path)):
#      11     dir_entry_path = os.path.join(path, dir_entry)
#      12     if os.path.isfile(dir_entry_path):
#
# FileNotFoundError: [WinError 3] Системе не удается найти указанный путь: 'C:\\Users\\Mikhail\\Desktop\\PracticeKaggle\\d2'

# %% [markdown]
# Переведём типы движений в числа

# %%
classes = {'standing' : 0, 'walking' : 1, 'run' : 2, 'bicycle' : 3, 'stairs' : 4, 
           'car' : 5, 'carPass' : 5, 'subway' : 6, 'escooter' : 7, 'kickscooter' : 8}

answers = {'стояние' : 0, 'ходьба' : 1, 'бег' : 2, 'велосипед' : 3, 'лестница' : 4, 
           'автомобиль' : 5, 'метро' : 6, 'электросамокат' : 7, 'самокат' : 8}

# стояние, ходьба, велосипед, лестница, бег, подъем, подъём, автомобиль, электросамокат, машина, метро

# %%
def get_action(name):
    for act in classes:
        if name.lower().find(act) != -1:
            return classes[act]
    return -1

# %% [markdown]
# Обработаем данные и извлечём признаки для создания модели

# %%
import pandas as pd
from matplotlib import pylab as plt
# %pylab inline

def process_data(df, comma=True, cut=True, name = "", a=-1, b=-1):
    
# обрезаем начало и конец трека
    if a == -1:
        st = 1250
    else:
        st = a
            
    if b == -1:
        end = -1250
    else:
        end = b
        
    if cut == False:
        st = 0
        end = -1

    print(name)
#     fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, figsize=(15,6))

# приводим данные с Iphone к нужному формату
    if comma is True:
        df = df.applymap(lambda x: str(x).replace(',','.'))
        
        try:
            df['gFx'] = df['gFx'].astype(float)
            df['gFy'] = df['gFy'].astype(float)
            df['gFz'] = df['gFz'].astype(float)
        except KeyError:
            return -1

# рисуем графики ускорений
#     if cut:
#         ax1.plot(df.iloc[st:end]['gFx'],c='g')
#         ax1.plot(df.iloc[st:end]['gFy'],c='r')
#         ax1.plot(df.iloc[st:end]['gFz'],c='b')
#     else:
#         ax1.plot(df['gFx'],c='g')
#         ax1.plot(df['gFy'],c='r')
#         ax1.plot(df['gFz'],c='b')
        
# вычисляем модуль (норму) ускорения и рисуем его
    Acc = (df.gFx[st:end] ** 2 + df.gFy[st:end] ** 2 + df.gFz[st:end] ** 2) ** 0.5
#     ax2.plot(Acc)
#     plt.show()

# можно различить многие действия по амплитуде ускорения
    amplitude = Acc.max() - Acc.min()
    print(' АМПЛИТУДА:', Acc.max()-Acc.min())
    print()
    
    return amplitude

Ampl = []
for df, target in zip(Data,Target):
    Ampl.append(process_data(df, name=target))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# bicycle_0.csv
#  АМПЛИТУДА: 1.737443347204773
#
# bicycle_10.csv
# F:\Users\Mikhail\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +
#  АМПЛИТУДА: 2.6604023570662245
#
# bicycle_11.csv
#  АМПЛИТУДА: 4.644639698243827
#
# bicycle_12.csv
#  АМПЛИТУДА: 5.01790999329792
#
# bicycle_34.csv
#  АМПЛИТУДА: 11.244971453275912
#
# bicycle_35.csv
#  АМПЛИТУДА: 6.664047760682303
#
# bicycle_36.csv
#  АМПЛИТУДА: 8.01468177354848
#
# bicycle_37.csv
#  АМПЛИТУДА: 5.849199292034639
#
# bicycle_47.csv
#  АМПЛИТУДА: 2.1636555900942884
#
# bicycle_48.csv
#  АМПЛИТУДА: 2.400429482183318
#
# bicycle_49.csv
#  АМПЛИТУДА: 3.0938383782019363
#
# bicycle_5.csv
#  АМПЛИТУДА: 4.773982292684448
#
# bicycle_50.csv
#  АМПЛИТУДА: 1.8431067775861552
#
# bicycle_51.csv
#  АМПЛИТУДА: 4.704149240560825
#
# bicycle_52.csv
#  АМПЛИТУДА: 8.601454843955032
#
# bicycle_53.csv
#  АМПЛИТУДА: 9.342162601824318
#
# bicycle_54.csv
#  АМПЛИТУДА: 8.0204589986997
#
# bicycle_59.csv
#  АМПЛИТУДА: 3.4965636600354926
#
# bicycle_6.csv
#  АМПЛИТУДА: 4.083700574260776
#
# bicycle_60.csv
#  АМПЛИТУДА: 4.249916886889521
#
# bicycle_7.csv
#  АМПЛИТУДА: 2.935880284391403
#
# bicycle_8.csv
#  АМПЛИТУДА: 3.6001313503195433
#
# bicycle_9.csv
#  АМПЛИТУДА: 3.23850834116677
#
# carPass_2.csv
#  АМПЛИТУДА: 1.043611419802445
#
# carPass_3.csv
#  АМПЛИТУДА: 0.8892260849383883
#
# carPass_4.csv
#  АМПЛИТУДА: 0.44531707136346477
#
# carPass_5.csv
#  АМПЛИТУДА: 0.7055621128199762
#
# carPass_6.csv
#  АМПЛИТУДА: 0.7793214161077002
#
# carPass_7.csv
#  АМПЛИТУДА: 1.5610455684711169
#
# carPass_8.csv
#  АМПЛИТУДА: 0.9321026179833166
#
# carPass_9.csv
#  АМПЛИТУДА: 1.5030481516897325
#
# car_4.csv
#  АМПЛИТУДА: 1.037319895576775
#
# car_5.csv
#  АМПЛИТУДА: 0.7523704108839862
#
# car_6.csv
#  АМПЛИТУДА: 0.8144227623218061
#
# car_7.csv
#  АМПЛИТУДА: 1.4864509500097176
#
# car_8.csv
#  АМПЛИТУДА: 1.000750977499247
#
# escooter_0.csv
#  АМПЛИТУДА: 4.826057105048199
#
# escooter_1.csv
#  АМПЛИТУДА: 2.410506842128974
#
# escooter_2.csv
#  АМПЛИТУДА: 5.715746624782869
#
# escooter_3.csv
#  АМПЛИТУДА: 4.082408318640019
#
# escooter_4.csv
#  АМПЛИТУДА: 2.014808003124357
#
# escooter_5.csv
#  АМПЛИТУДА: 1.9327218477785124
#
# escooter_6.csv
#  АМПЛИТУДА: 2.4931279715998125
#
# escooter_7.csv
#  АМПЛИТУДА: 1.7773134151447478
#
# escooter_8.csv
#  АМПЛИТУДА: 1.8245846117041524
#
# run_10.csv
#  АМПЛИТУДА: 5.883807542449248
#
# run_101.csv
#  АМПЛИТУДА: 8.047079634370618
#
# run_102.csv
#  АМПЛИТУДА: 6.088536054270766
#
# run_103.csv
#  АМПЛИТУДА: 5.158433595653463
#
# run_104.csv
#  АМПЛИТУДА: 6.306884806992486
#
# run_105.csv
#  АМПЛИТУДА: 7.782164725912398
#
# run_106.csv
#  АМПЛИТУДА: 7.122722531878146
#
# run_107.csv
#  АМПЛИТУДА: 7.086178138626245
#
# run_108.csv
#  АМПЛИТУДА: 6.863422900253244
#
# run_11.csv
#  АМПЛИТУДА: 5.651776091858696
#
# run_116.csv
#  АМПЛИТУДА: 7.6275172394763135
#
# run_117.csv
#  АМПЛИТУДА: 3.9412311960455364
#
# run_118.csv
#  АМПЛИТУДА: 3.7865767485957167
#
# run_119.csv
#  АМПЛИТУДА: 4.895521847236084
#
# run_139.csv
#  АМПЛИТУДА: 5.074736639122914
#
# run_140.csv
#  АМПЛИТУДА: 4.767163290619636
#
# run_141.csv
#  АМПЛИТУДА: 6.736057329257273
#
# run_142.csv
#  АМПЛИТУДА: 4.227569169453173
#
# run_152.csv
#  АМПЛИТУДА: 10.240096948811768
#
# run_153.csv
#  АМПЛИТУДА: 10.2618300659755
#
# run_154.csv
#  АМПЛИТУДА: 11.009051640040123
#
# run_155.csv
#  АМПЛИТУДА: 10.956512893405963
#
# run_176.csv
#  АМПЛИТУДА: 2.9281453313951404
#
# run_185.csv
#  АМПЛИТУДА: 7.9377776657050845
#
# run_186.csv
#  АМПЛИТУДА: 7.536510448194547
#
# run_187.csv
#  АМПЛИТУДА: 7.980123432881462
#
# run_188.csv
#  АМПЛИТУДА: 7.626571647663388
#
# run_189.csv
#  АМПЛИТУДА: 8.569267071173995
#
# run_190.csv
#  АМПЛИТУДА: 8.468451551965419
#
# run_191.csv
#  АМПЛИТУДА: 7.3542514036338975
#
# run_192.csv
#  АМПЛИТУДА: 8.521923613123398
#
# run_193.csv
#  АМПЛИТУДА: 8.342834731039337
#
# run_194.csv
#  АМПЛИТУДА: 12.459103326762934
#
# run_195.csv
#  АМПЛИТУДА: 9.758101960315168
#
# run_196.csv
#  АМПЛИТУДА: 9.721117683944023
#
# run_197.csv
#  АМПЛИТУДА: 10.206174558422564
#
# run_198.csv
#  АМПЛИТУДА: 4.820829324214449
#
# run_199.csv
#  АМПЛИТУДА: 11.707697708885535
#
# run_200.csv
#  АМПЛИТУДА: 11.253572425257714
#
# run_201.csv
#  АМПЛИТУДА: 9.079688757020355
#
# run_202.csv
#  АМПЛИТУДА: 10.315162932739716
#
# run_203.csv
#  АМПЛИТУДА: 9.558228219592639
#
# run_204.csv
#  АМПЛИТУДА: 5.077233501659604
#
# run_205.csv
#  АМПЛИТУДА: 8.33584714677042
#
# run_206.csv
#  АМПЛИТУДА: 5.153043639298749
#
# run_207.csv
#  АМПЛИТУДА: 9.014825422070176
#
# run_208.csv
#  АМПЛИТУДА: 8.5273186514731
#
# run_209.csv
#  АМПЛИТУДА: 10.944023154208098
#
# run_21.csv
#  АМПЛИТУДА: 9.736080946471649
#
# run_210.csv
#  АМПЛИТУДА: 9.451455441063418
#
# run_211.csv
#  АМПЛИТУДА: 11.426269576111638
#
# run_212.csv
#  АМПЛИТУДА: 3.5411219034989587
#
# run_213.csv
#  АМПЛИТУДА: 3.386968959387318
#
# run_214.csv
#  АМПЛИТУДА: 3.3791632873384714
#
# run_215.csv
#  АМПЛИТУДА: 2.567384189171995
#
# run_216.csv
#  АМПЛИТУДА: 4.300026389138519
#
# run_217.csv
#  АМПЛИТУДА: 6.294071758371258
#
# run_22.csv
#  АМПЛИТУДА: 10.837278933096472
#
# run_31.csv
#  АМПЛИТУДА: 4.109209800764568
#
# run_32.csv
#  АМПЛИТУДА: 4.059655024232354
#
# run_33.csv
#  АМПЛИТУДА: 5.194690889883821
#
# run_34.csv
#  АМПЛИТУДА: 5.256061308817652
#
# run_44.csv
#  АМПЛИТУДА: 11.557383108672834
#
# run_45.csv
#  АМПЛИТУДА: 11.453290655534735
#
# run_46.csv
#  АМПЛИТУДА: 11.313718331121306
#
# run_47.csv
#  АМПЛИТУДА: 11.38653238008329
#
# run_48.csv
#  АМПЛИТУДА: 10.032331849598053
#
# run_49.csv
#  АМПЛИТУДА: 8.534033402859269
#
# run_50.csv
#  АМПЛИТУДА: 9.337798683871293
#
# run_51.csv
#  АМПЛИТУДА: 8.38992265664194
#
# run_56.csv
#  АМПЛИТУДА: 4.217408740765442
#
# run_57.csv
#  АМПЛИТУДА: 4.446016710631592
#
# run_58.csv
#  АМПЛИТУДА: 4.607105085383815
#
# run_59.csv
#  АМПЛИТУДА: 4.77002564809945
#
# run_74.csv
#  АМПЛИТУДА: 5.930509196752689
#
# run_75.csv
#  АМПЛИТУДА: 6.375018589782778
#
# run_76.csv
#  АМПЛИТУДА: 6.613037882405666
#
# run_77.csv
#  АМПЛИТУДА: 6.58861443841474
#
# run_78.csv
#  АМПЛИТУДА: 7.079172271324158
#
# run_8.csv
#  АМПЛИТУДА: 5.60987925898751
#
# run_84.csv
#  АМПЛИТУДА: 7.449291606502653
#
# run_85.csv
#  АМПЛИТУДА: 6.625263652643367
#
# run_86.csv
#  АМПЛИТУДА: 7.098123910881596
#
# run_87.csv
#  АМПЛИТУДА: 7.235090332315696
#
# run_9.csv
#  АМПЛИТУДА: 5.690848038252908
#
# stairs_0.csv
#  АМПЛИТУДА: 1.454416647715628
#
# stairs_119.csv
#  АМПЛИТУДА: 4.8201194341655205
#
# stairs_120.csv
#  АМПЛИТУДА: 4.852841611284205
#
# stairs_121.csv
#  АМПЛИТУДА: 4.421786329267485
#
# stairs_122.csv
#  АМПЛИТУДА: 6.144740699421437
#
# stairs_127.csv
#  АМПЛИТУДА: 1.5866132367040175
#
# stairs_128.csv
#  АМПЛИТУДА: 1.899615252211777
#
# stairs_129.csv
#  АМПЛИТУДА: 2.5570339654256804
#
# stairs_130.csv
#  АМПЛИТУДА: 1.7209249600585637
#
# stairs_149.csv
#  АМПЛИТУДА: 1.033387690393294
#
# stairs_150.csv
#  АМПЛИТУДА: 1.1368190830077312
#
# stairs_151.csv
#  АМПЛИТУДА: 2.111717436168516
#
# stairs_152.csv
#  АМПЛИТУДА: 3.1281340516464953
#
# stairs_153.csv
#  АМПЛИТУДА: 4.275899629200106
#
# stairs_154.csv
#  АМПЛИТУДА: 5.610212775777448
#
# stairs_155.csv
#  АМПЛИТУДА: 4.845181928512066
#
# stairs_156.csv
#  АМПЛИТУДА: 4.129419605710527
#
# stairs_157.csv
#  АМПЛИТУДА: 0.9535997958236004
#
# stairs_158.csv
#  АМПЛИТУДА: 0.9729993031129127
#
# stairs_159.csv
#  АМПЛИТУДА: 1.04157897020418
#
# stairs_160.csv
#  АМПЛИТУДА: 1.190808899181734
#
# stairs_161.csv
#  АМПЛИТУДА: 3.3234120677520314
#
# stairs_162.csv
#  АМПЛИТУДА: 4.6175761168999845
#
# stairs_163.csv
#  АМПЛИТУДА: 3.570706465474359
#
# stairs_164.csv
#  АМПЛИТУДА: 4.3922429663905795
#
# stairs_165.csv
#  АМПЛИТУДА: 3.451963042830861
#
# stairs_17.csv
#  АМПЛИТУДА: 3.881317628351139
#
# stairs_179.csv
#  АМПЛИТУДА: 3.6678011402579083
#
# stairs_18.csv
#  АМПЛИТУДА: 1.6050896065900868
#
# stairs_182.csv
#  АМПЛИТУДА: 3.728697739089142
#
# stairs_19.csv
#  АМПЛИТУДА: 0.9773547639075321
#
# stairs_192.csv
#  АМПЛИТУДА: 0.9528367689833221
#
# stairs_193.csv
#  АМПЛИТУДА: 1.3730352400969803
#
# stairs_194.csv
#  АМПЛИТУДА: 2.8254171118253795
#
# stairs_199.csv
#  АМПЛИТУДА: 1.3163786688698798
#
# stairs_20.csv
#  АМПЛИТУДА: 0.8744089504293157
#
# stairs_204.csv
#  АМПЛИТУДА: 2.2590830933671566
#
# stairs_205.csv
#  АМПЛИТУДА: 2.3715620290717205
#
# stairs_206.csv
#  АМПЛИТУДА: 2.587572425068989
#
# stairs_207.csv
#  АМПЛИТУДА: 2.5322013273283313
#
# stairs_218.csv
#  АМПЛИТУДА: 2.538707914411852
#
# stairs_219.csv
#  АМПЛИТУДА: 1.689125450019033
#
# stairs_220.csv
#  АМПЛИТУДА: 2.2028634199506087
#
# stairs_221.csv
#  АМПЛИТУДА: 6.9934020039676055
#
# stairs_227.csv
#  АМПЛИТУДА: 1.5989377112493135
#
# stairs_228.csv
#  АМПЛИТУДА: 1.5821657322583613
#
# stairs_229.csv
#  АМПЛИТУДА: 1.560841617169553
#
# stairs_230.csv
#  АМПЛИТУДА: 5.801531956078153
#
# stairs_31.csv
#  АМПЛИТУДА: 7.478111092748063
#
# stairs_32.csv
#  АМПЛИТУДА: 7.8920827850102215
#
# stairs_33.csv
#  АМПЛИТУДА: 6.432398076731767
#
# stairs_34.csv
#  АМПЛИТУДА: 7.807886697895157
#
# stairs_42.csv
#  АМПЛИТУДА: 1.5531295559741283
#
# stairs_43.csv
#  АМПЛИТУДА: 1.476462986966591
#
# stairs_44.csv
#  АМПЛИТУДА: 4.1066991152620025
#
# stairs_45.csv
#  АМПЛИТУДА: 1.6510328764746793
#
# stairs_60.csv
#  АМПЛИТУДА: 3.537266726576554
#
# stairs_61.csv
#  АМПЛИТУДА: 3.36224762884661
#
# stairs_62.csv
#  АМПЛИТУДА: 4.065559956133192
#
# stairs_63.csv
#  АМПЛИТУДА: 6.9608583906899275
#
# stairs_64.csv
#  АМПЛИТУДА: 1.0521820895533958
#
# stairs_65.csv
#  АМПЛИТУДА: 0.7735648196864187
#
# stairs_66.csv
#  АМПЛИТУДА: 0.7857251713760568
#
# stairs_67.csv
#  АМПЛИТУДА: 1.3171461110511926
#
# stairs_72.csv
#  АМПЛИТУДА: 2.280293881983009
#
# stairs_73.csv
#  АМПЛИТУДА: 1.7252606610325871
#
# stairs_74.csv
#  АМПЛИТУДА: 4.204158585124877
#
# stairs_75.csv
#  АМПЛИТУДА: 3.6504546920999497
#
# stairs_76.csv
#  АМПЛИТУДА: 3.0456884258304093
#
# stairs_93.csv
#  АМПЛИТУДА: 4.703481907566621
#
# stairs_94.csv
#  АМПЛИТУДА: 12.08934479316191
#
# stairs_95.csv
#  АМПЛИТУДА: 5.861101882696465
#
# stairs_96.csv
#  АМПЛИТУДА: 4.003377996503552
#
# stairs_97.csv
#  АМПЛИТУДА: 4.156796287951986
#
# standing_0.csv
#  АМПЛИТУДА: 0.04860929182495932
#
# standing_1.csv
#  АМПЛИТУДА: 5.270792312361508
#
# standing_121.csv
#  АМПЛИТУДА: 0.4827649191254053
#
# standing_122.csv
#  АМПЛИТУДА: 0.05284425342345078
#
# standing_123.csv
#  АМПЛИТУДА: 0.0371332864084889
#
# standing_124.csv
#  АМПЛИТУДА: 0.2878391598553939
#
# standing_125.csv
#  АМПЛИТУДА: 0.057081495359672774
#
# standing_126.csv
#  АМПЛИТУДА: 0.06670072769932411
#
# standing_127.csv
#  АМПЛИТУДА: 0.41013656368380236
#
# standing_128.csv
#  АМПЛИТУДА: 0.1262513911183576
#
# standing_129.csv
#  АМПЛИТУДА: 0.13927060902150024
#
# standing_130.csv
#  АМПЛИТУДА: 0.10381915919312867
#
# standing_134.csv
#  АМПЛИТУДА: 0.40192524845429467
#
# standing_135.csv
#  АМПЛИТУДА: 0.08247976509109922
#
# standing_136.csv
#  АМПЛИТУДА: 3.1549236356254307
#
# standing_137.csv
#  АМПЛИТУДА: 0.19425966338310363
#
# standing_138.csv
#  АМПЛИТУДА: 0.09633295205671077
#
# standing_158.csv
#  АМПЛИТУДА: 0.14155316758088532
#
# standing_159.csv
#  АМПЛИТУДА: 0.26127116784753857
#
# standing_160.csv
#  АМПЛИТУДА: 1.2058977967497824
#
# standing_161.csv
#  АМПЛИТУДА: 0.3852896262903014
#
# standing_162.csv
#  АМПЛИТУДА: 2.44140345311437
#
# standing_163.csv
#  АМПЛИТУДА: 3.4979011707144307
#
# standing_164.csv
#  АМПЛИТУДА: 3.044974448625231
#
# standing_165.csv
#  АМПЛИТУДА: 3.5353965048286042
#
# standing_177.csv
#  АМПЛИТУДА: 0.2649338176195335
#
# standing_178.csv
#  АМПЛИТУДА: 0.4457873294990984
#
# standing_179.csv
#  АМПЛИТУДА: 0.0712797303449787
#
# standing_180.csv
#  АМПЛИТУДА: 0.25827738181837956
#
# standing_2.csv
#  АМПЛИТУДА: 2.275255034339257
#
# standing_201.csv
#  АМПЛИТУДА: 2.2008020086028433
#
# standing_202.csv
#  АМПЛИТУДА: 3.5548838499730406
#
# standing_203.csv
#  АМПЛИТУДА: 1.929394520291362
#
# standing_204.csv
#  АМПЛИТУДА: 2.9244963335907608
#
# standing_205.csv
#  АМПЛИТУДА: 1.357086567303089
#
# standing_206.csv
#  АМПЛИТУДА: 0.11884506305777165
#
# standing_207.csv
#  АМПЛИТУДА: 0.10702642655813266
#
# standing_208.csv
#  АМПЛИТУДА: 0.10015948950077769
#
# standing_209.csv
#  АМПЛИТУДА: 0.0158581128781784
#
# standing_210.csv
#  АМПЛИТУДА: 0.05436320750399026
#
# standing_211.csv
#  АМПЛИТУДА: 0.01996935695352775
#
# standing_212.csv
#  АМПЛИТУДА: 0.07242025109088635
#
# standing_213.csv
#  АМПЛИТУДА: 0.03917081767314223
#
# standing_214.csv
#  АМПЛИТУДА: 0.03606001682760129
#
# standing_215.csv
#  АМПЛИТУДА: 0.03670415570306962
#
# standing_216.csv
#  АМПЛИТУДА: 0.04073189987258918
#
# standing_217.csv
#  АМПЛИТУДА: 0.07774970779527424
#
# standing_231.csv
#  АМПЛИТУДА: 0.23428373608324382
#
# standing_232.csv
#  АМПЛИТУДА: 0.16287302240142698
#
# standing_233.csv
#  АМПЛИТУДА: 0.1970303957055929
#
# standing_234.csv
#  АМПЛИТУДА: 0.12304387658222338
#
# standing_235.csv
#  АМПЛИТУДА: 0.026249378090874687
#
# standing_245.csv
#  АМПЛИТУДА: 2.818181101906656
#
# standing_246.csv
#  АМПЛИТУДА: 1.2951269064737174
#
# standing_247.csv
#  АМПЛИТУДА: 3.280368408464594
#
# standing_248.csv
#  АМПЛИТУДА: 0.17933940456643105
#
# standing_249.csv
#  АМПЛИТУДА: 0.47175809906545974
#
# standing_258.csv
#  АМПЛИТУДА: 0.06790940143194935
#
# standing_259.csv
#  АМПЛИТУДА: 0.21097324353993074
#
# standing_26.csv
#  АМПЛИТУДА: 0.22471523359873014
#
# standing_260.csv
#  АМПЛИТУДА: 2.6070640107943164
#
# standing_27.csv
#  АМПЛИТУДА: 0.1900809185776664
#
# standing_273.csv
#  АМПЛИТУДА: 0.024302972619481444
#
# standing_274.csv
#  АМПЛИТУДА: 0.022110644573492877
#
# standing_275.csv
#  АМПЛИТУДА: 0.5141353340948094
#
# standing_276.csv
#  АМПЛИТУДА: 0.09984973905721872
#
# standing_28.csv
#  АМПЛИТУДА: 0.10433834747410375
#
# standing_29.csv
#  АМПЛИТУДА: 0.518851171606359
#
# standing_3.csv
#  АМПЛИТУДА: 2.2123933524011954
#
# standing_4.csv
#  АМПЛИТУДА: 2.2248244856296555
#
# standing_40.csv
#  АМПЛИТУДА: 1.8077863497261895
#
# standing_41.csv
#  АМПЛИТУДА: 2.8462752089628287
#
# standing_42.csv
#  АМПЛИТУДА: 2.4822574119658594
#
# standing_43.csv
#  АМПЛИТУДА: 1.7774064092567052
#
# standing_52.csv
#  АМПЛИТУДА: 0.2693908677715614
#
# standing_53.csv
#  АМПЛИТУДА: 0.042733988483578456
#
# standing_54.csv
#  АМПЛИТУДА: 0.032347472933042076
#
# standing_55.csv
#  АМПЛИТУДА: 0.21335147298769186
#
# standing_64.csv
#  АМПЛИТУДА: 0.023758431897028864
#
# standing_65.csv
#  АМПЛИТУДА: 0.026939247140325473
#
# standing_66.csv
#  АМПЛИТУДА: 0.01614781893004269
#
# standing_67.csv
#  АМПЛИТУДА: 0.04733714384885046
#
# standing_68.csv
#  АМПЛИТУДА: 0.17877142375463062
#
# standing_69.csv
#  АМПЛИТУДА: 0.0882415842665022
#
# standing_70.csv
#  АМПЛИТУДА: 0.09044047051773108
#
# standing_71.csv
#  АМПЛИТУДА: 0.07836765623364905
#
# standing_72.csv
#  АМПЛИТУДА: 0.018033372308140727
#
# standing_78.csv
#  АМПЛИТУДА: 0.039261186227083966
#
# standing_79.csv
#  АМПЛИТУДА: 0.030091082240103817
#
# standing_80.csv
#  АМПЛИТУДА: 0.03610234371029175
#
# standing_81.csv
#  АМПЛИТУДА: 0.048069946439978306
#
# standing_82.csv
#  АМПЛИТУДА: 0.6459714587026006
#
# standing_83.csv
#  АМПЛИТУДА: 0.6339855385892813
#
# standing_84.csv
#  АМПЛИТУДА: 0.6111156406607853
#
# standing_85.csv
#  АМПЛИТУДА: 0.2980415592927297
#
# standing_86.csv
#  АМПЛИТУДА: 0.7160966549544262
#
# standing_91.csv
#  АМПЛИТУДА: 0.049488081853028776
#
# standing_92.csv
#  АМПЛИТУДА: 0.13432054278468097
#
# standing_93.csv
#  АМПЛИТУДА: 0.050871807491953636
#
# standing_94.csv
#  АМПЛИТУДА: 0.08673568889876138
#
# standing_95.csv
#  АМПЛИТУДА: 0.38776000426417356
#
# standing_96.csv
#  АМПЛИТУДА: 0.19079589139606679
#
# standing_97.csv
#  АМПЛИТУДА: 6.900679901945982
#
# standing_98.csv
#  АМПЛИТУДА: 0.06573892865690245
#
# standing_99.csv
#  АМПЛИТУДА: 0.15938193133148326
#
# subway_5.csv
#  АМПЛИТУДА: 0.5707533535111868
#
# subway_6.csv
#  АМПЛИТУДА: 0.42040456788504554
#
# subway_7.csv
#  АМПЛИТУДА: 0.3636556821738858
#
# subway_8.csv
#  АМПЛИТУДА: 0.5275966168907505
#
# walking_0.csv
#  АМПЛИТУДА: 1.6036375086044719
#
# walking_1.csv
#  АМПЛИТУДА: 4.910559261985718
#
# walking_127.csv
#  АМПЛИТУДА: 2.630337260411962
#
# walking_128.csv
#  АМПЛИТУДА: 1.399958810156114
#
# walking_129.csv
#  АМПЛИТУДА: 2.0145905728393174
#
# walking_130.csv
#  АМПЛИТУДА: 4.540697283017482
#
# walking_131.csv
#  АМПЛИТУДА: 2.308384707593478
#
# walking_132.csv
#  АМПЛИТУДА: 3.4190392779245067
#
# walking_133.csv
#  АМПЛИТУДА: 2.743821081120647
#
# walking_134.csv
#  АМПЛИТУДА: 3.0234657480273746
#
# walking_146.csv
#  АМПЛИТУДА: 1.1956195497773532
#
# walking_147.csv
#  АМПЛИТУДА: 1.2624076846927919
#
# walking_148.csv
#  АМПЛИТУДА: 1.0890809114538786
#
# walking_149.csv
#  АМПЛИТУДА: 0.9916179001596825
#
# walking_15.csv
#  АМПЛИТУДА: 2.041924499394278
#
# walking_16.csv
#  АМПЛИТУДА: 2.116128510980079
#
# walking_17.csv
#  АМПЛИТУДА: 2.6749993435458923
#
# walking_170.csv
#  АМПЛИТУДА: 3.3066704951125057
#
# walking_171.csv
#  АМПЛИТУДА: 2.642378970699479
#
# walking_18.csv
#  АМПЛИТУДА: 2.156041610178825
#
# walking_184.csv
#  АМПЛИТУДА: 2.861182966227448
#
# walking_185.csv
#  АМПЛИТУДА: 2.7762392691519446
#
# walking_186.csv
#  АМПЛИТУДА: 5.076848264391839
#
# walking_187.csv
#  АМПЛИТУДА: 3.7233104373762766
#
# walking_196.csv
#  АМПЛИТУДА: 1.4498050286182305
#
# walking_197.csv
#  АМПЛИТУДА: 1.7381852285837147
#
# walking_198.csv
#  АМПЛИТУДА: 2.766688928637509
#
# walking_199.csv
#  АМПЛИТУДА: 1.4849966083106452
#
# walking_2.csv
#  АМПЛИТУДА: 7.554956632660712
#
# walking_228.csv
#  АМПЛИТУДА: 5.5655459870235555
#
# walking_229.csv
#  АМПЛИТУДА: 3.729020088181414
#
# walking_230.csv
#  АМПЛИТУДА: 3.934661841563937
#
# walking_231.csv
#  АМПЛИТУДА: 3.9201881832104504
#
# walking_232.csv
#  АМПЛИТУДА: 9.885328985596342
#
# walking_233.csv
#  АМПЛИТУДА: 7.47569933458179
#
# walking_234.csv
#  АМПЛИТУДА: 10.50220475754128
#
# walking_235.csv
#  АМПЛИТУДА: 10.386097847632348
#
# walking_236.csv
#  АМПЛИТУДА: 1.5646973515591833
#
# walking_241.csv
#  АМПЛИТУДА: 4.064548087827115
#
# walking_242.csv
#  АМПЛИТУДА: 4.837779750487028
#
# walking_243.csv
#  АМПЛИТУДА: 4.333593268457219
#
# walking_244.csv
#  АМПЛИТУДА: 4.50128931388739
#
# walking_245.csv
#  АМПЛИТУДА: 5.275176818207058
#
# walking_246.csv
#  АМПЛИТУДА: 3.1345378975461413
#
# walking_247.csv
#  АМПЛИТУДА: 5.371652442742002
#
# walking_248.csv
#  АМПЛИТУДА: 4.787971654672504
#
# walking_249.csv
#  АМПЛИТУДА: 5.248055745766442
#
# walking_250.csv
#  АМПЛИТУДА: 4.013805945948069
#
# walking_251.csv
#  АМПЛИТУДА: 2.09219589199181
#
# walking_252.csv
#  АМПЛИТУДА: 4.696905532866923
#
# walking_253.csv
#  АМПЛИТУДА: 1.344106625400895
#
# walking_254.csv
#  АМПЛИТУДА: 3.8866563227409854
#
# walking_255.csv
#  АМПЛИТУДА: 3.768798044823656
#
# walking_256.csv
#  АМПЛИТУДА: 4.573429853056476
#
# walking_257.csv
#  АМПЛИТУДА: 3.8042296325615337
#
# walking_258.csv
#  АМПЛИТУДА: 4.360095055468569
#
# walking_259.csv
#  АМПЛИТУДА: 0.9366255937236542
#
# walking_260.csv
#  АМПЛИТУДА: 0.9407104643115772
#
# walking_261.csv
#  АМПЛИТУДА: 0.7221028475024486
#
# walking_262.csv
#  АМПЛИТУДА: 0.7446967132983474
#
# walking_263.csv
#  АМПЛИТУДА: 4.988959052550203
#
# walking_264.csv
#  АМПЛИТУДА: 4.742621153309791
#
# walking_265.csv
#  АМПЛИТУДА: 5.191106839396584
#
# walking_266.csv
#  АМПЛИТУДА: 8.204283920149129
#
# walking_267.csv
#  АМПЛИТУДА: 5.079893702393587
#
# walking_268.csv
#  АМПЛИТУДА: 1.756637849940128
#
# walking_269.csv
#  АМПЛИТУДА: 1.4019874829379972
#
# walking_270.csv
#  АМПЛИТУДА: 3.2679099785755352
#
# walking_271.csv
#  АМПЛИТУДА: 2.5665329938137393
#
# walking_272.csv
#  АМПЛИТУДА: 2.7624870255900893
#
# walking_273.csv
#  АМПЛИТУДА: 2.074913965345143
#
# walking_274.csv
#  АМПЛИТУДА: 2.085712484661602
#
# walking_275.csv
#  АМПЛИТУДА: 2.141081337884539
#
# walking_276.csv
#  АМПЛИТУДА: 1.4410749646076408
#
# walking_277.csv
#  АМПЛИТУДА: 1.8358567455126371
#
# walking_278.csv
#  АМПЛИТУДА: 1.5020684911458146
#
# walking_279.csv
#  АМПЛИТУДА: 1.620282703099679
#
# walking_280.csv
#  АМПЛИТУДА: 3.968491044559421
#
# walking_281.csv
#  АМПЛИТУДА: 4.577768623132259
#
# walking_282.csv
#  АМПЛИТУДА: 5.532456276657836
#
# walking_283.csv
#  АМПЛИТУДА: 6.381972599001904
#
# walking_284.csv
#  АМПЛИТУДА: 1.4973519122069947
#
# walking_285.csv
#  АМПЛИТУДА: 1.2824427466829396
#
# walking_286.csv
#  АМПЛИТУДА: 1.4912904054675895
#
# walking_287.csv
#  АМПЛИТУДА: 1.2925103523385386
#
# walking_288.csv
#  АМПЛИТУДА: 1.58003445751662
#
# walking_29.csv
#  АМПЛИТУДА: 5.5950801302266076
#
# walking_3.csv
#  АМПЛИТУДА: 4.967362371614219
#
# walking_30.csv
#  АМПЛИТУДА: 5.5543733288394
#
# walking_31.csv
#  АМПЛИТУДА: 4.767369224923368
#
# walking_4.csv
#  АМПЛИТУДА: 5.5216663650689535
#
# walking_40.csv
#  АМПЛИТУДА: 2.3570850480333747
#
# walking_41.csv
#  АМПЛИТУДА: 1.815145606703863
#
# walking_42.csv
#  АМПЛИТУДА: 1.8010806512491266
#
# walking_43.csv
#  АМПЛИТУДА: 1.5266056935049959
#
# walking_57.csv
#  АМПЛИТУДА: 2.635233687414674
#
# walking_58.csv
#  АМПЛИТУДА: 3.165562540089324
#
# walking_59.csv
#  АМПЛИТУДА: 4.112322797160363
#
# walking_60.csv
#  АМПЛИТУДА: 3.930980320072668
#
# walking_61.csv
#  АМПЛИТУДА: 1.7663743442528799
#
# walking_62.csv
#  АМПЛИТУДА: 1.9527459148631416
#
# walking_63.csv
#  АМПЛИТУДА: 1.9331959098539633
#
# walking_64.csv
#  АМПЛИТУДА: 1.8068905544828462
#
# walking_69.csv
#  АМПЛИТУДА: 1.9386702892094032
#
# walking_70.csv
#  АМПЛИТУДА: 1.9259107392421553
#
# walking_71.csv
#  АМПЛИТУДА: 1.8637075733336412
#
# walking_72.csv
#  АМПЛИТУДА: 1.855236231104529
#
# walking_81.csv
# walking_93.csv
#  АМПЛИТУДА: 3.795844795174871
#
# walking_94.csv
#  АМПЛИТУДА: 3.2261452431312825
#
# walking_95.csv
#  АМПЛИТУДА: 2.8462214174018077
#
# walking_96.csv
#  АМПЛИТУДА: 3.6501025004462737
#
# bicycle_1.csv
#  АМПЛИТУДА: 0.887233728594633
#
# bicycle_17.csv
#  АМПЛИТУДА: 2.8630642115087643
#
# bicycle_18.csv
#  АМПЛИТУДА: 1.9386691890225622
#
# bicycle_19.csv
#  АМПЛИТУДА: 1.853858040267265
#
# bicycle_2.csv
#  АМПЛИТУДА: 0.534754542833331
#
# bicycle_20.csv
#  АМПЛИТУДА: 1.395075267202805
#
# bicycle_21.csv
#  АМПЛИТУДА: 1.3876886523710017
#
# bicycle_22.csv
#  АМПЛИТУДА: 4.071373210251039
#
# bicycle_23.csv
#  АМПЛИТУДА: 3.8025905410132435
#
# bicycle_24.csv
#  АМПЛИТУДА: 3.0882204453777247
#
# bicycle_25.csv
#  АМПЛИТУДА: 2.51160714376787
#
# bicycle_26.csv
#  АМПЛИТУДА: 2.3897680467432942
#
# bicycle_27.csv
#  АМПЛИТУДА: 1.9482240203894063
#
# bicycle_28.csv
#  АМПЛИТУДА: 2.745448105632711
#
# bicycle_29.csv
#  АМПЛИТУДА: 4.731562225177925
#
# bicycle_3.csv
#  АМПЛИТУДА: 0.47375425893974277
#
# bicycle_30.csv
#  АМПЛИТУДА: 1.991326144158299
#
# bicycle_31.csv
#  АМПЛИТУДА: 6.423952888247974
#
# bicycle_32.csv
#  АМПЛИТУДА: 4.2486847953992095
#
# bicycle_33.csv
#  АМПЛИТУДА: 1.3003862144312404
#
# bicycle_38.csv
#  АМПЛИТУДА: 2.104080739658354
#
# bicycle_39.csv
#  АМПЛИТУДА: 3.625196690815626
#
# bicycle_4.csv
#  АМПЛИТУДА: 0.6555380958317613
#
# bicycle_40.csv
#  АМПЛИТУДА: 3.0868081400419793
#
# bicycle_41.csv
#  АМПЛИТУДА: 3.7899410512251555
#
# bicycle_42.csv
#  АМПЛИТУДА: nan
#
# bicycle_43.csv
#  АМПЛИТУДА: 2.222194727566806
#
# bicycle_44.csv
#  АМПЛИТУДА: 1.242328573641498
#
# bicycle_45.csv
#  АМПЛИТУДА: 1.4094016558386613
#
# bicycle_46.csv
#  АМПЛИТУДА: 1.9169783451820368
#
# bicycle_55.csv
#  АМПЛИТУДА: 0.9797927184740838
#
# bicycle_56.csv
#  АМПЛИТУДА: 1.2774604105189216
#
# bicycle_57.csv
#  АМПЛИТУДА: 2.217685559722047
#
# bicycle_58.csv
#  АМПЛИТУДА: 2.1606900971158374
#
# carPass_0.csv
#  АМПЛИТУДА: 1.1058099077748866
#
# carPass_1.csv
#  АМПЛИТУДА: 0.6084465548685073
#
# car_0.csv
#  АМПЛИТУДА: 0.9810442232748544
#
# car_1.csv
#  АМПЛИТУДА: 0.5972402040749221
#
# car_10.csv
#  АМПЛИТУДА: 0.9983561089100621
#
# car_11.csv
#  АМПЛИТУДА: 0.9605507009000966
#
# car_12.csv
#  АМПЛИТУДА: 1.075232146114657
#
# car_13.csv
#  АМПЛИТУДА: 0.6140742541286204
#
# car_14.csv
#  АМПЛИТУДА: 0.8058482413441607
#
# car_15.csv
#  АМПЛИТУДА: 0.5997893297664261
#
# car_16.csv
#  АМПЛИТУДА: 0.5386474725391591
#
# car_17.csv
#  АМПЛИТУДА: 0.970254341156362
#
# car_18.csv
#  АМПЛИТУДА: 1.0126089528887894
#
# car_19.csv
#  АМПЛИТУДА: 0.4166379266779888
#
# car_2.csv
#  АМПЛИТУДА: 0.6634144541827448
#
# car_20.csv
#  АМПЛИТУДА: 0.7169206231664856
#
# car_21.csv
#  АМПЛИТУДА: 1.4732805235453597
#
# car_22.csv
#  АМПЛИТУДА: 0.6110885429613898
#
# car_23.csv
#  АМПЛИТУДА: 0.4240431350157743
#
# car_24.csv
#  АМПЛИТУДА: 1.159031455437074
#
# car_25.csv
#  АМПЛИТУДА: 0.6439780799042588
#
# car_26.csv
#  АМПЛИТУДА: 0.4799607672837074
#
# car_27.csv
#  АМПЛИТУДА: 0.4210935278342808
#
# car_28.csv
#  АМПЛИТУДА: 0.6239762115916395
#
# car_3.csv
#  АМПЛИТУДА: 1.2575679325760325
#
# car_9.csv
#  АМПЛИТУДА: 0.7400614402688165
#
# escooter_10.csv
#  АМПЛИТУДА: 5.097644415885659
#
# escooter_11.csv
#  АМПЛИТУДА: 3.3102756619349436
#
# escooter_12.csv
#  АМПЛИТУДА: 3.6189021350414103
#
# escooter_9.csv
#  АМПЛИТУДА: 3.278699940599883
#
# kickscooter_0.csv
#  АМПЛИТУДА: nan
#
# kickscooter_1.csv
#  АМПЛИТУДА: nan
#
# kickscooter_10.csv
#  АМПЛИТУДА: nan
#
# kickscooter_11.csv
#  АМПЛИТУДА: nan
#
# kickscooter_2.csv
#  АМПЛИТУДА: nan
#
# kickscooter_3.csv
#  АМПЛИТУДА: nan
#
# kickscooter_4.csv
#  АМПЛИТУДА: nan
#
# kickscooter_5.csv
#  АМПЛИТУДА: nan
#
# kickscooter_6.csv
#  АМПЛИТУДА: nan
#
# kickscooter_7.csv
#  АМПЛИТУДА: nan
#
# kickscooter_8.csv
#  АМПЛИТУДА: nan
#
# kickscooter_9.csv
#  АМПЛИТУДА: nan
#
# run_0.csv
#  АМПЛИТУДА: 4.75830007216539
#
# run_1.csv
#  АМПЛИТУДА: 4.159195865638438
#
# run_100.csv
#  АМПЛИТУДА: 5.286700423551823
#
# run_109.csv
#  АМПЛИТУДА: nan
#
# run_110.csv
#  АМПЛИТУДА: 7.077661928670496
#
# run_111.csv
#  АМПЛИТУДА: 7.332053541175354
#
# run_112.csv
#  АМПЛИТУДА: 7.336722741085522
#
# run_113.csv
#  АМПЛИТУДА: 8.158552842694691
#
# run_114.csv
#  АМПЛИТУДА: 7.279637404373835
#
# run_115.csv
#  АМПЛИТУДА: 1.5829736314222569
#
# run_12.csv
#  АМПЛИТУДА: 7.835147972268137
#
# run_120.csv
#  АМПЛИТУДА: 8.147744101831263
#
# run_121.csv
#  АМПЛИТУДА: 8.115093476262414
#
# run_122.csv
#  АМПЛИТУДА: 8.062389739759686
#
# run_123.csv
#  АМПЛИТУДА: 8.496071762151622
#
# run_124.csv
#  АМПЛИТУДА: 6.685565281770715
#
# run_125.csv
#  АМПЛИТУДА: 5.594732996333308
#
# run_126.csv
#  АМПЛИТУДА: 7.537278599399508
#
# run_127.csv
#  АМПЛИТУДА: 6.632205554631362
#
# run_128.csv
#  АМПЛИТУДА: 7.460947769671498
#
# run_129.csv
#  АМПЛИТУДА: 5.76043244194417
#
# run_13.csv
#  АМПЛИТУДА: 8.068731322921396
#
# run_130.csv
#  АМПЛИТУДА: 6.394483653196255
#
# run_131.csv
#  АМПЛИТУДА: 6.822430335591489
#
# run_132.csv
#  АМПЛИТУДА: 6.176586115192287
#
# run_133.csv
#  АМПЛИТУДА: 6.725674675382648
#
# run_134.csv
#  АМПЛИТУДА: 9.224968771096176
#
# run_135.csv
#  АМПЛИТУДА: 8.60293028367404
#
# run_136.csv
#  АМПЛИТУДА: 9.078193743299732
#
# run_137.csv
#  АМПЛИТУДА: 8.905838391341772
#
# run_138.csv
#  АМПЛИТУДА: 10.15469619211539
#
# run_14.csv
#  АМПЛИТУДА: 7.28622307060518
#
# run_143.csv
#  АМПЛИТУДА: 10.623515152341058
#
# run_144.csv
#  АМПЛИТУДА: 11.573990359512038
#
# run_145.csv
#  АМПЛИТУДА: 9.840067945197418
#
# run_146.csv
#  АМПЛИТУДА: 8.221837546288727
#
# run_147.csv
#  АМПЛИТУДА: 9.000318782147463
#
# run_148.csv
#  АМПЛИТУДА: 8.464994070270075
#
# run_149.csv
#  АМПЛИТУДА: 9.792557416144565
#
# run_15.csv
#  АМПЛИТУДА: nan
#
# run_150.csv
#  АМПЛИТУДА: 8.590770966639802
#
# run_151.csv
#  АМПЛИТУДА: 9.824356594978797
#
# run_156.csv
#  АМПЛИТУДА: 5.235370183545134
#
# run_157.csv
#  АМПЛИТУДА: 5.1072917159360065
#
# run_158.csv
#  АМПЛИТУДА: 5.784092324819335
#
# run_159.csv
#  АМПЛИТУДА: 4.09551530529293
#
# run_16.csv
#  АМПЛИТУДА: 7.376276708180853
#
# run_160.csv
#  АМПЛИТУДА: 8.994205261956898
#
# run_161.csv
#  АМПЛИТУДА: 9.104559067519016
#
# run_162.csv
#  АМПЛИТУДА: 9.758384449117441
#
# run_163.csv
#  АМПЛИТУДА: 9.838614641802932
#
# run_164.csv
#  АМПЛИТУДА: 6.777016316224333
#
# run_165.csv
#  АМПЛИТУДА: 8.833872151590114
#
# run_166.csv
#  АМПЛИТУДА: 8.393178613355369
#
# run_167.csv
#  АМПЛИТУДА: 7.92348512718009
#
# run_168.csv
#  АМПЛИТУДА: 10.407201342331527
#
# run_169.csv
#  АМПЛИТУДА: 7.907553798171549
#
# run_17.csv
#  АМПЛИТУДА: 5.938512043301991
#
# run_170.csv
#  АМПЛИТУДА: 10.68190684630775
#
# run_171.csv
#  АМПЛИТУДА: 10.635780289924677
#
# run_177.csv
#  АМПЛИТУДА: 0.38627581292043023
#
# run_178.csv
#  АМПЛИТУДА: 0.38627581292043023
#
# run_179.csv
#  АМПЛИТУДА: nan
#
# run_18.csv
#  АМПЛИТУДА: 6.203918836348656
#
# run_180.csv
#  АМПЛИТУДА: nan
#
# run_181.csv
#  АМПЛИТУДА: 7.020563327163986
#
# run_182.csv
#  АМПЛИТУДА: 7.020563327163986
#
# run_183.csv
#  АМПЛИТУДА: nan
#
# run_184.csv
#  АМПЛИТУДА: nan
#
# run_19.csv
#  АМПЛИТУДА: 5.405680939352176
#
# run_2.csv
#  АМПЛИТУДА: 4.188173165779974
#
# run_20.csv
#  АМПЛИТУДА: 7.441245900887786
#
# run_23.csv
#  АМПЛИТУДА: 7.1992336999983895
#
# run_24.csv
#  АМПЛИТУДА: 6.628066720552236
#
# run_25.csv
#  АМПЛИТУДА: 6.735302506994073
#
# run_26.csv
#  АМПЛИТУДА: 7.318116528265742
#
# run_27.csv
#  АМПЛИТУДА: 5.520635998638725
#
# run_28.csv
#  АМПЛИТУДА: 7.664125957254541
#
# run_29.csv
#  АМПЛИТУДА: 5.339006025527848
#
# run_3.csv
#  АМПЛИТУДА: 4.758311959979781
#
# run_30.csv
#  АМПЛИТУДА: 5.150564419468778
#
# run_35.csv
#  АМПЛИТУДА: 10.725248446677769
#
# run_36.csv
#  АМПЛИТУДА: 8.508426840214035
#
# run_37.csv
#  АМПЛИТУДА: 9.192586800867423
#
# run_38.csv
#  АМПЛИТУДА: 9.23497270434618
#
# run_39.csv
#  АМПЛИТУДА: 8.10727523342417
#
# run_4.csv
#  АМПЛИТУДА: 0.38627581292043023
#
# run_40.csv
#  АМПЛИТУДА: 7.6420680495318445
#
# run_41.csv
#  АМПЛИТУДА: 6.61961371000526
#
# run_42.csv
#  АМПЛИТУДА: 7.941607616356142
#
# run_43.csv
#  АМПЛИТУДА: 6.373970126289841
#
# run_5.csv
#  АМПЛИТУДА: nan
#
# run_52.csv
#  АМПЛИТУДА: 2.565079119608928
#
# run_53.csv
#  АМПЛИТУДА: 3.9386277692519216
#
# run_54.csv
#  АМПЛИТУДА: 4.312603959026855
#
# run_55.csv
#  АМПЛИТУДА: 3.687778541967808
#
# run_6.csv
#  АМПЛИТУДА: 7.020563327163986
#
# run_60.csv
#  АМПЛИТУДА: 6.0305608178429635
#
# run_61.csv
#  АМПЛИТУДА: 6.818080158391286
#
# run_62.csv
#  АМПЛИТУДА: 6.493960727205453
#
# run_63.csv
#  АМПЛИТУДА: 4.110755044568008
#
# run_64.csv
#  АМПЛИТУДА: 8.629298704448438
#
# run_65.csv
#  АМПЛИТУДА: 8.963570583191704
#
# run_66.csv
#  АМПЛИТУДА: 9.486291842430226
#
# run_67.csv
#  АМПЛИТУДА: 9.57745245995737
#
# run_68.csv
#  АМПЛИТУДА: 9.952526398731138
#
# run_69.csv
#  АМПЛИТУДА: 3.6623077635144172
#
# run_7.csv
#  АМПЛИТУДА: nan
#
# run_70.csv
#  АМПЛИТУДА: 6.350236931648284
#
# run_71.csv
#  АМПЛИТУДА: 7.118988067888508
#
# run_72.csv
#  АМПЛИТУДА: 5.88148457435741
#
# run_73.csv
#  АМПЛИТУДА: 8.875617892191908
#
# run_79.csv
#  АМПЛИТУДА: 6.1429989543056065
#
# run_80.csv
#  АМПЛИТУДА: 7.264161504621193
#
# run_81.csv
#  АМПЛИТУДА: 8.23682994018906
#
# run_82.csv
#  АМПЛИТУДА: 7.48929709196796
#
# run_83.csv
#  АМПЛИТУДА: 5.425812455007947
#
# run_88.csv
#  АМПЛИТУДА: 10.197603438350258
#
# run_89.csv
#  АМПЛИТУДА: 6.360489605581641
#
# run_90.csv
#  АМПЛИТУДА: 7.307405507737051
#
# run_91.csv
#  АМПЛИТУДА: 7.96091662626318
#
# run_92.csv
#  АМПЛИТУДА: 2.901278762697561
#
# run_93.csv
#  АМПЛИТУДА: 3.1678950268247665
#
# run_94.csv
#  АМПЛИТУДА: 2.9690180329855176
#
# run_95.csv
#  АМПЛИТУДА: 4.784809681717607
#
# run_96.csv
#  АМПЛИТУДА: 3.194626811697645
#
# run_97.csv
#  АМПЛИТУДА: 3.5554586606107357
#
# run_98.csv
#  АМПЛИТУДА: 7.079653916109764
#
# run_99.csv
#  АМПЛИТУДА: 5.519315649970301
#
# stairs_1.csv
#  АМПЛИТУДА: 1.9844820167055934
#
# stairs_10.csv
#  АМПЛИТУДА: nan
#
# stairs_100.csv
#  АМПЛИТУДА: 3.416673236426811
#
# stairs_101.csv
#  АМПЛИТУДА: 1.0347632261010589
#
# stairs_102.csv
#  АМПЛИТУДА: 4.177183602014071
#
# stairs_103.csv
#  АМПЛИТУДА: 4.64700095965119
#
# stairs_104.csv
#  АМПЛИТУДА: 5.1903941039413874
#
# stairs_105.csv
#  АМПЛИТУДА: 5.4945758443801775
#
# stairs_106.csv
#  АМПЛИТУДА: 2.9048204696710087
#
# stairs_107.csv
#  АМПЛИТУДА: 3.6317423193931377
#
# stairs_108.csv
#  АМПЛИТУДА: 3.2264595931651465
#
# stairs_109.csv
#  АМПЛИТУДА: 4.829450933622133
#
# stairs_11.csv
#  АМПЛИТУДА: nan
#
# stairs_110.csv
#  АМПЛИТУДА: 1.927928370823622
#
# stairs_111.csv
#  АМПЛИТУДА: 2.6427028161596025
#
# stairs_112.csv
#  АМПЛИТУДА: 3.2142217448026305
#
# stairs_113.csv
#  АМПЛИТУДА: 1.8768665717974946
#
# stairs_114.csv
#  АМПЛИТУДА: 2.962422116820663
#
# stairs_115.csv
#  АМПЛИТУДА: 2.0465201565439504
#
# stairs_116.csv
#  АМПЛИТУДА: 2.0411410353712185
#
# stairs_117.csv
#  АМПЛИТУДА: 2.3167628671238942
#
# stairs_118.csv
#  АМПЛИТУДА: 1.1885607449420248
#
# stairs_12.csv
#  АМПЛИТУДА: nan
#
# stairs_123.csv
#  АМПЛИТУДА: nan
#
# stairs_124.csv
#  АМПЛИТУДА: nan
#
# stairs_125.csv
#  АМПЛИТУДА: nan
#
# stairs_126.csv
#  АМПЛИТУДА: nan
#
# stairs_13.csv
#  АМПЛИТУДА: nan
#
# stairs_131.csv
#  АМПЛИТУДА: 5.157553705469328
#
# stairs_132.csv
#  АМПЛИТУДА: 3.882725493916183
#
# stairs_133.csv
#  АМПЛИТУДА: 4.360697762475361
#
# stairs_134.csv
#  АМПЛИТУДА: 4.147648259579905
#
# stairs_135.csv
#  АМПЛИТУДА: 1.255816259627678
#
# stairs_136.csv
#  АМПЛИТУДА: 1.1654592303516762
#
# stairs_137.csv
#  АМПЛИТУДА: 1.1062598270185058
#
# stairs_138.csv
#  АМПЛИТУДА: 1.3482875197568833
#
# stairs_139.csv
#  АМПЛИТУДА: 1.4159636268783982
#
# stairs_14.csv
#  АМПЛИТУДА: nan
#
# stairs_140.csv
#  АМПЛИТУДА: 3.1996074189554387
#
# stairs_141.csv
#  АМПЛИТУДА: 2.812123841846535
#
# stairs_142.csv
#  АМПЛИТУДА: 3.979564868018822
#
# stairs_143.csv
#  АМПЛИТУДА: 2.6934649226206955
#
# stairs_144.csv
#  АМПЛИТУДА: 4.103981089025842
#
# stairs_145.csv
#  АМПЛИТУДА: 3.326804710520382
#
# stairs_146.csv
#  АМПЛИТУДА: 4.74346736950009
#
# stairs_147.csv
#  АМПЛИТУДА: 4.293156269856327
#
# stairs_148.csv
#  АМПЛИТУДА: 3.7280278006730696
#
# stairs_15.csv
#  АМПЛИТУДА: nan
#
# stairs_16.csv
#  АМПЛИТУДА: nan
#
# stairs_166.csv
#  АМПЛИТУДА: 3.3703949562343927
#
# stairs_167.csv
#  АМПЛИТУДА: 3.666904652160056
#
# stairs_168.csv
#  АМПЛИТУДА: 3.4654539863693024
#
# stairs_169.csv
#  АМПЛИТУДА: 4.082163005983795
#
# stairs_170.csv
#  АМПЛИТУДА: 0.6193032612143985
#
# stairs_171.csv
#  АМПЛИТУДА: 2.6485675052447837
#
# stairs_172.csv
#  АМПЛИТУДА: 1.8825394616334608
#
# stairs_173.csv
#  АМПЛИТУДА: 1.4377068104705182
#
# stairs_174.csv
#  АМПЛИТУДА: 2.2688361544668805
#
# stairs_175.csv
#  АМПЛИТУДА: 4.182278559842229
#
# stairs_176.csv
#  АМПЛИТУДА: 4.540949279619203
#
# stairs_177.csv
#  АМПЛИТУДА: 4.397705517640331
#
# stairs_178.csv
#  АМПЛИТУДА: 4.592643413094023
#
# stairs_183.csv
#  АМПЛИТУДА: 0.9678087424374162
#
# stairs_184.csv
#  АМПЛИТУДА: 1.9573182180768163
#
# stairs_185.csv
#  АМПЛИТУДА: 1.7869311233137493
#
# stairs_186.csv
#  АМПЛИТУДА: 1.3462076334196902
#
# stairs_187.csv
#  АМПЛИТУДА: 2.176649300381148
#
# stairs_188.csv
#  АМПЛИТУДА: 5.439711706689996
#
# stairs_189.csv
#  АМПЛИТУДА: 4.555817285736007
#
# stairs_190.csv
#  АМПЛИТУДА: 3.5004516747555274
#
# stairs_191.csv
#  АМПЛИТУДА: 3.9648441048675087
#
# stairs_195.csv
#  АМПЛИТУДА: 1.809884085092134
#
# stairs_196.csv
#  АМПЛИТУДА: 3.0090261139255987
#
# stairs_197.csv
#  АМПЛИТУДА: 3.207376194883045
#
# stairs_198.csv
#  АМПЛИТУДА: 2.9468671687746717
#
# stairs_2.csv
#  АМПЛИТУДА: 3.228322334766254
#
# stairs_200.csv
#  АМПЛИТУДА: 2.5165745208673123
#
# stairs_201.csv
#  АМПЛИТУДА: 2.9300995718918657
#
# stairs_202.csv
#  АМПЛИТУДА: 3.2958938824659354
#
# stairs_203.csv
#  АМПЛИТУДА: 2.5117025342508783
#
# stairs_208.csv
#  АМПЛИТУДА: 1.1979521688023382
#
# stairs_209.csv
#  АМПЛИТУДА: 1.4570430891646813
#
# stairs_21.csv
#  АМПЛИТУДА: 2.890644668817676
#
# stairs_210.csv
#  АМПЛИТУДА: 2.13992465560345
#
# stairs_211.csv
#  АМПЛИТУДА: 2.750556629756889
#
# stairs_212.csv
#  АМПЛИТУДА: 2.083039203457419
#
# stairs_213.csv
#  АМПЛИТУДА: 2.941359935938098
#
# stairs_214.csv
#  АМПЛИТУДА: 3.0545775923710385
#
# stairs_215.csv
#  АМПЛИТУДА: nan
#
# stairs_216.csv
#  АМПЛИТУДА: 2.425519996816373
#
# stairs_217.csv
#  АМПЛИТУДА: 1.4199032128398748
#
# stairs_22.csv
#  АМПЛИТУДА: 2.5553391765566236
#
# stairs_222.csv
#  АМПЛИТУДА: 0.7819846728956726
#
# stairs_223.csv
#  АМПЛИТУДА: 1.6747853585284782
#
# stairs_224.csv
#  АМПЛИТУДА: 2.337822607491704
#
# stairs_225.csv
#  АМПЛИТУДА: 1.7657270040723585
#
# stairs_226.csv
#  АМПЛИТУДА: 1.5935180424746311
#
# stairs_23.csv
#  АМПЛИТУДА: 0.8701230742826227
#
# stairs_231.csv
#  АМПЛИТУДА: 1.61416363780364
#
# stairs_24.csv
#  АМПЛИТУДА: 1.0201706766887884
#
# stairs_25.csv
#  АМПЛИТУДА: 3.1773385538422643
#
# stairs_26.csv
#  АМПЛИТУДА: 1.4747053242095136
#
# stairs_27.csv
#  АМПЛИТУДА: 1.6496838250080268
#
# stairs_28.csv
#  АМПЛИТУДА: 1.6610441530883704
#
# stairs_29.csv
#  АМПЛИТУДА: 1.3251785024455762
#
# stairs_3.csv
#  АМПЛИТУДА: 4.110078252956978
#
# stairs_30.csv
#  АМПЛИТУДА: 1.134586790809931
#
# stairs_35.csv
#  АМПЛИТУДА: 2.6427017396268666
#
# stairs_36.csv
#  АМПЛИТУДА: 2.749354846034551
#
# stairs_37.csv
#  АМПЛИТУДА: 2.2547466687278805
#
# stairs_38.csv
#  АМПЛИТУДА: 2.6364379613418447
#
# stairs_39.csv
#  АМПЛИТУДА: 2.7557181589912583
#
# stairs_4.csv
#  АМПЛИТУДА: 4.436903351173556
#
# stairs_40.csv
#  АМПЛИТУДА: 3.0648116343446974
#
# stairs_41.csv
#  АМПЛИТУДА: 2.6518214229822403
#
# stairs_46.csv
#  АМПЛИТУДА: 3.4177281814962845
#
# stairs_47.csv
#  АМПЛИТУДА: 3.4346242449781674
#
# stairs_48.csv
#  АМПЛИТУДА: 3.8483818117251993
#
# stairs_49.csv
#  АМПЛИТУДА: 4.284306484914855
#
# stairs_5.csv
#  АМПЛИТУДА: nan
#
# stairs_50.csv
#  АМПЛИТУДА: nan
#
# stairs_51.csv
#  АМПЛИТУДА: nan
#
# stairs_52.csv
#  АМПЛИТУДА: nan
#
# stairs_53.csv
#  АМПЛИТУДА: nan
#
# stairs_54.csv
#  АМПЛИТУДА: nan
#
# stairs_55.csv
#  АМПЛИТУДА: 1.4726854458913468
#
# stairs_56.csv
#  АМПЛИТУДА: 1.4023570000998666
#
# stairs_57.csv
#  АМПЛИТУДА: 1.621711236520799
#
# stairs_58.csv
#  АМПЛИТУДА: 1.9196165407024641
#
# stairs_59.csv
#  АМПЛИТУДА: 1.6410387596026887
#
# stairs_6.csv
#  АМПЛИТУДА: nan
#
# stairs_68.csv
#  АМПЛИТУДА: 1.0559678311158414
#
# stairs_69.csv
#  АМПЛИТУДА: 2.9566253237566626
#
# stairs_7.csv
#  АМПЛИТУДА: nan
#
# stairs_70.csv
#  АМПЛИТУДА: 1.4814431898129068
#
# stairs_71.csv
#  АМПЛИТУДА: 2.5514930912764013
#
# stairs_77.csv
#  АМПЛИТУДА: 4.089953064426431
#
# stairs_78.csv
#  АМПЛИТУДА: 4.0389965448370955
#
# stairs_79.csv
#  АМПЛИТУДА: 3.727982166462982
#
# stairs_8.csv
#  АМПЛИТУДА: nan
#
# stairs_80.csv
#  АМПЛИТУДА: 4.647921406406962
#
# stairs_85.csv
#  АМПЛИТУДА: 3.283474968943659
#
# stairs_86.csv
#  АМПЛИТУДА: 1.4724126238645752
#
# stairs_87.csv
#  АМПЛИТУДА: 1.6974395862199705
#
# stairs_88.csv
#  АМПЛИТУДА: 2.1687750415414677
#
# stairs_89.csv
#  АМПЛИТУДА: 1.484858146478012
#
# stairs_9.csv
#  АМПЛИТУДА: nan
#
# stairs_90.csv
#  АМПЛИТУДА: 1.0533244885508837
#
# stairs_91.csv
#  АМПЛИТУДА: 1.4745888654054649
#
# stairs_92.csv
#  АМПЛИТУДА: 1.679308769970903
#
# stairs_98.csv
#  АМПЛИТУДА: 2.940023469374965
#
# stairs_99.csv
#  АМПЛИТУДА: 3.877910321034239
#
# standing_10.csv
#  АМПЛИТУДА: 0.1349177357867335
#
# standing_100.csv
#  АМПЛИТУДА: 0.08774167516721465
#
# standing_101.csv
#  АМПЛИТУДА: 0.11899244005017073
#
# standing_102.csv
#  АМПЛИТУДА: 0.7812626468147204
#
# standing_103.csv
#  АМПЛИТУДА: 0.03253467180515357
#
# standing_104.csv
#  АМПЛИТУДА: 0.010691965961089567
#
# standing_105.csv
#  АМПЛИТУДА: 0.06153960441706818
#
# standing_106.csv
#  АМПЛИТУДА: 0.26017869294057194
#
# standing_107.csv
#  АМПЛИТУДА: 0.07586916232696994
#
# standing_108.csv
#  АМПЛИТУДА: 0.20266105360181608
#
# standing_109.csv
#  АМПЛИТУДА: 0.19000024665812132
#
# standing_11.csv
#  АМПЛИТУДА: 0.17715556480562966
#
# standing_110.csv
#  АМПЛИТУДА: 0.1828074562369416
#
# standing_111.csv
#  АМПЛИТУДА: 0.20668219879257166
#
# standing_112.csv
#  АМПЛИТУДА: 0.030327945267279
#
# standing_113.csv
#  АМПЛИТУДА: 0.04427500187958466
#
# standing_114.csv
#  АМПЛИТУДА: 0.06495719453342186
#
# standing_115.csv
#  АМПЛИТУДА: 0.10371003922370114
#
# standing_116.csv
#  АМПЛИТУДА: 0.10731457344648876
#
# standing_117.csv
#  АМПЛИТУДА: nan
#
# standing_118.csv
#  АМПЛИТУДА: 0.01828443657245593
#
# standing_119.csv
#  АМПЛИТУДА: 0.013716128081947554
#
# standing_12.csv
#  АМПЛИТУДА: 0.5443440449710197
#
# standing_120.csv
#  АМПЛИТУДА: 0.018238696865952697
#
# standing_13.csv
#  АМПЛИТУДА: 0.8477140277345941
#
# standing_131.csv
#  АМПЛИТУДА: 0.040945858210477915
#
# standing_132.csv
#  АМПЛИТУДА: 0.035265914048235425
#
# standing_133.csv
#  АМПЛИТУДА: 0.03273994111453393
#
# standing_139.csv
#  АМПЛИТУДА: 0.04964223375352639
#
# standing_14.csv
#  АМПЛИТУДА: nan
#
# standing_140.csv
#  АМПЛИТУДА: 0.23409082832176165
#
# standing_141.csv
#  АМПЛИТУДА: 0.04156817184366657
#
# standing_142.csv
#  АМПЛИТУДА: 0.03242715105646854
#
# standing_143.csv
#  АМПЛИТУДА: 0.03180402838167362
#
# standing_144.csv
#  АМПЛИТУДА: 0.030619786496004275
#
# standing_145.csv
#  АМПЛИТУДА: 0.15049487985819243
#
# standing_146.csv
#  АМПЛИТУДА: 0.11213198073539432
#
# standing_147.csv
#  АМПЛИТУДА: 0.1267089828394562
#
# standing_148.csv
#  АМПЛИТУДА: 0.04887848842400233
#
# standing_149.csv
#  АМПЛИТУДА: 0.08325849863134127
#
# standing_15.csv
#  АМПЛИТУДА: nan
#
# standing_150.csv
#  АМПЛИТУДА: 0.8887962531568271
#
# standing_151.csv
#  АМПЛИТУДА: 0.029622850558605807
#
# standing_152.csv
#  АМПЛИТУДА: 0.021746129920682256
#
# standing_153.csv
#  АМПЛИТУДА: 0.014171992105327158
#
# standing_154.csv
#  АМПЛИТУДА: 0.008049852759012044
#
# standing_155.csv
#  АМПЛИТУДА: 0.009048397097959793
#
# standing_156.csv
#  АМПЛИТУДА: 0.010078627683087094
#
# standing_157.csv
#  АМПЛИТУДА: 0.007949900287769207
#
# standing_16.csv
#  АМПЛИТУДА: nan
#
# standing_166.csv
#  АМПЛИТУДА: nan
#
# standing_167.csv
#  АМПЛИТУДА: nan
#
# standing_168.csv
#  АМПЛИТУДА: nan
#
# standing_169.csv
#  АМПЛИТУДА: nan
#
# standing_17.csv
#  АМПЛИТУДА: nan
#
# standing_170.csv
#  АМПЛИТУДА: nan
#
# standing_171.csv
#  АМПЛИТУДА: 0.017103251744187475
#
# standing_172.csv
#  АМПЛИТУДА: 0.07608888241325673
#
# standing_173.csv
#  АМПЛИТУДА: 0.12482923926615475
#
# standing_174.csv
#  АМПЛИТУДА: 0.13452735941424665
#
# standing_175.csv
#  АМПЛИТУДА: 0.06230320620906593
#
# standing_176.csv
#  АМПЛИТУДА: 1.1591739528475085
#
# standing_18.csv
#  АМПЛИТУДА: nan
#
# standing_181.csv
#  АМПЛИТУДА: 0.041196843164382324
#
# standing_182.csv
#  АМПЛИТУДА: 0.01637095740794181
#
# standing_183.csv
#  АМПЛИТУДА: 0.023884020063908662
#
# standing_184.csv
#  АМПЛИТУДА: 0.019147097126432255
#
# standing_185.csv
#  АМПЛИТУДА: 0.04069697676646056
#
# standing_186.csv
#  АМПЛИТУДА: 0.03021127831276138
#
# standing_187.csv
#  АМПЛИТУДА: 0.08306844566674942
#
# standing_188.csv
#  АМПЛИТУДА: 0.045255674439810045
#
# standing_189.csv
#  АМПЛИТУДА: 0.03435171356552558
#
# standing_19.csv
#  АМПЛИТУДА: nan
#
# standing_190.csv
#  АМПЛИТУДА: 0.04561513512279647
#
# standing_191.csv
#  АМПЛИТУДА: 0.03625278626666251
#
# standing_192.csv
#  АМПЛИТУДА: 0.021218330975929622
#
# standing_193.csv
#  АМПЛИТУДА: 0.025452500846487647
#
# standing_194.csv
#  АМПЛИТУДА: 0.018359576811421197
#
# standing_195.csv
#  АМПЛИТУДА: 0.045674720246950296
#
# standing_196.csv
#  АМПЛИТУДА: 0.02393331657683806
#
# standing_197.csv
#  АМПЛИТУДА: 0.2566907538415457
#
# standing_198.csv
#  АМПЛИТУДА: 0.1158043041385165
#
# standing_199.csv
#  АМПЛИТУДА: 0.08060882695309624
#
# standing_20.csv
#  АМПЛИТУДА: nan
#
# standing_200.csv
#  АМПЛИТУДА: 0.11155539049568419
#
# standing_21.csv
#  АМПЛИТУДА: nan
#
# standing_218.csv
#  АМПЛИТУДА: 0.6445512391712742
#
# standing_219.csv
#  АМПЛИТУДА: 0.04718978882299252
#
# standing_22.csv
#  АМПЛИТУДА: nan
#
# standing_220.csv
#  АМПЛИТУДА: 0.15400273716496882
#
# standing_221.csv
#  АМПЛИТУДА: 0.07150980794272355
#
# standing_222.csv
#  АМПЛИТУДА: 0.018315537155559225
#
# standing_223.csv
#  АМПЛИТУДА: 0.019250541429577273
#
# standing_224.csv
#  АМПЛИТУДА: 0.030039019291474123
#
# standing_225.csv
#  АМПЛИТУДА: 0.011495658265505249
#
# standing_226.csv
#  АМПЛИТУДА: 0.011545159137667516
#
# standing_227.csv
#  АМПЛИТУДА: 0.2069667062047602
#
# standing_228.csv
#  АМПЛИТУДА: 0.10667499118122581
#
# standing_229.csv
#  АМПЛИТУДА: 0.16192126863144107
#
# standing_23.csv
#  АМПЛИТУДА: nan
#
# standing_230.csv
#  АМПЛИТУДА: 0.6463739516204583
#
# standing_236.csv
#  АМПЛИТУДА: nan
#
# standing_237.csv
#  АМПЛИТУДА: nan
#
# standing_238.csv
#  АМПЛИТУДА: nan
#
# standing_239.csv
#  АМПЛИТУДА: nan
#
# standing_24.csv
#  АМПЛИТУДА: nan
#
# standing_240.csv
#  АМПЛИТУДА: nan
#
# standing_241.csv
#  АМПЛИТУДА: 0.21528298620160613
#
# standing_242.csv
#  АМПЛИТУДА: 0.11434940268133398
#
# standing_243.csv
#  АМПЛИТУДА: 0.6460885678849753
#
# standing_244.csv
#  АМПЛИТУДА: 0.3108708416095117
#
# standing_25.csv
#  АМПЛИТУДА: nan
#
# standing_250.csv
#  АМПЛИТУДА: 1.8572412523149873
#
# standing_251.csv
#  АМПЛИТУДА: 10.545204449110134
#
# standing_252.csv
#  АМПЛИТУДА: 0.3057761438969421
#
# standing_253.csv
#  АМПЛИТУДА: 3.1912922935260473
#
# standing_254.csv
#  АМПЛИТУДА: 0.03413485281354034
#
# standing_255.csv
#  АМПЛИТУДА: 0.013839638111782349
#
# standing_256.csv
#  АМПЛИТУДА: 0.0060907832784860005
#
# standing_257.csv
#  АМПЛИТУДА: 0.00503216550745611
#
# standing_261.csv
#  АМПЛИТУДА: 0.035225130372368185
#
# standing_262.csv
#  АМПЛИТУДА: 0.06111374623409305
#
# standing_263.csv
#  АМПЛИТУДА: 0.002999499190354693
#
# standing_264.csv
#  АМПЛИТУДА: 0.004047088192103643
#
# standing_265.csv
#  АМПЛИТУДА: 0.0174550621447479
#
# standing_266.csv
#  АМПЛИТУДА: 0.037196414640237485
#
# standing_267.csv
#  АМПЛИТУДА: 0.08851528004243336
#
# standing_268.csv
#  АМПЛИТУДА: 0.22633644386332952
#
# standing_269.csv
#  АМПЛИТУДА: 0.2220717146853063
#
# standing_270.csv
#  АМПЛИТУДА: 0.1380342320088369
#
# standing_271.csv
#  АМПЛИТУДА: 0.07354343229938154
#
# standing_272.csv
#  АМПЛИТУДА: 0.05180641219910542
#
# standing_281.csv
#  АМПЛИТУДА: 0.09664837104206547
#
# standing_30.csv
#  АМПЛИТУДА: 0.07049542088242455
#
# standing_31.csv
#  АМПЛИТУДА: nan
#
# standing_32.csv
#  АМПЛИТУДА: nan
#
# standing_33.csv
#  АМПЛИТУДА: nan
#
# standing_34.csv
#  АМПЛИТУДА: nan
#
# standing_35.csv
#  АМПЛИТУДА: 0.021110216240023738
#
# standing_36.csv
#  АМПЛИТУДА: 0.05032287621357601
#
# standing_37.csv
#  АМПЛИТУДА: 0.03570136844918348
#
# standing_38.csv
#  АМПЛИТУДА: 0.06471491767676263
#
# standing_39.csv
#  АМПЛИТУДА: 0.03283902173908915
#
# standing_44.csv
#  АМПЛИТУДА: 0.1174820346759411
#
# standing_45.csv
#  АМПЛИТУДА: 0.14925637085238463
#
# standing_46.csv
#  АМПЛИТУДА: 0.12295543549048338
#
# standing_47.csv
#  АМПЛИТУДА: 0.07715395273955528
#
# standing_48.csv
#  АМПЛИТУДА: 0.08732091380050322
#
# standing_49.csv
#  АМПЛИТУДА: 0.07760100116533131
#
# standing_5.csv
#  АМПЛИТУДА: 0.05092642201353592
#
# standing_50.csv
#  АМПЛИТУДА: 0.012545995759355444
#
# standing_51.csv
#  АМПЛИТУДА: 0.011052107728084182
#
# standing_56.csv
#  АМПЛИТУДА: 0.017106834178061137
#
# standing_57.csv
#  АМПЛИТУДА: 0.27476352265459414
#
# standing_58.csv
#  АМПЛИТУДА: 0.16823684803661743
#
# standing_59.csv
#  АМПЛИТУДА: 0.03243658458164722
#
# standing_6.csv
#  АМПЛИТУДА: 0.035319515430635384
#
# standing_60.csv
#  АМПЛИТУДА: nan
#
# standing_61.csv
#  АМПЛИТУДА: nan
#
# standing_62.csv
#  АМПЛИТУДА: nan
#
# standing_63.csv
#  АМПЛИТУДА: nan
#
# standing_7.csv
#  АМПЛИТУДА: 0.04267580802705895
#
# standing_73.csv
#  АМПЛИТУДА: 0.013086850948061723
#
# standing_74.csv
#  АМПЛИТУДА: 0.030973464344872026
#
# standing_75.csv
#  АМПЛИТУДА: 0.012883255715436026
#
# standing_76.csv
#  АМПЛИТУДА: 0.013620687479496296
#
# standing_77.csv
#  АМПЛИТУДА: 0.013083610191111261
#
# standing_8.csv
#  АМПЛИТУДА: 0.04964223375352639
#
# standing_87.csv
#  АМПЛИТУДА: 0.02112182074788349
#
# standing_88.csv
#  АМПЛИТУДА: 0.031018319853087895
#
# standing_89.csv
#  АМПЛИТУДА: 0.015247527367162172
#
# standing_9.csv
#  АМПЛИТУДА: 0.11898962991409567
#
# standing_90.csv
#  АМПЛИТУДА: 0.030141749456268685
#
# subway_0.csv
#  АМПЛИТУДА: 0.23734383025525774
#
# subway_1.csv
#  АМПЛИТУДА: 0.8753902290983566
#
# subway_10.csv
#  АМПЛИТУДА: 0.4384406752197121
#
# subway_11.csv
#  АМПЛИТУДА: 0.23686501799875603
#
# subway_12.csv
#  АМПЛИТУДА: 0.24881081748949052
#
# subway_2.csv
#  АМПЛИТУДА: nan
#
# subway_3.csv
#  АМПЛИТУДА: 0.2516911913675437
#
# subway_4.csv
#  АМПЛИТУДА: 0.17784101643805184
#
# subway_9.csv
#  АМПЛИТУДА: 0.38707151985708677
#
# walking_10.csv
#  АМПЛИТУДА: 4.135341793324986
#
# walking_100.csv
#  АМПЛИТУДА: 1.7177611593517927
#
# walking_101.csv
#  АМПЛИТУДА: 6.264545823981603
#
# walking_102.csv
#  АМПЛИТУДА: 7.17044960202376
#
# walking_103.csv
#  АМПЛИТУДА: 7.19347871526468
#
# walking_104.csv
#  АМПЛИТУДА: 5.93645132414515
#
# walking_105.csv
#  АМПЛИТУДА: 5.0103722896175285
#
# walking_106.csv
#  АМПЛИТУДА: 2.168779714024668
#
# walking_107.csv
#  АМПЛИТУДА: 4.138742613251943
#
# walking_108.csv
#  АМПЛИТУДА: 2.412178347806623
#
# walking_109.csv
#  АМПЛИТУДА: 5.755268286198687
#
# walking_11.csv
#  АМПЛИТУДА: 0.07752103505737651
#
# walking_110.csv
#  АМПЛИТУДА: 1.9483539025503864
#
# walking_111.csv
#  АМПЛИТУДА: 1.599501186424902
#
# walking_112.csv
#  АМПЛИТУДА: 2.36034233946211
#
# walking_113.csv
#  АМПЛИТУДА: 2.459246050487
#
# walking_114.csv
#  АМПЛИТУДА: 4.054112813142812
#
# walking_115.csv
#  АМПЛИТУДА: 3.416380297016943
#
# walking_116.csv
#  АМПЛИТУДА: 2.848041521390372
#
# walking_117.csv
#  АМПЛИТУДА: 3.3204185814253337
#
# walking_118.csv
#  АМПЛИТУДА: 2.5743657894844487
#
# walking_119.csv
#  АМПЛИТУДА: 2.0177065397032394
#
# walking_12.csv
#  АМПЛИТУДА: 0.06506261007654968
#
# walking_120.csv
#  АМПЛИТУДА: 2.2644866214558625
#
# walking_121.csv
#  АМПЛИТУДА: 2.341986012396642
#
# walking_122.csv
#  АМПЛИТУДА: 1.6895628855569158
#
# walking_123.csv
#  АМПЛИТУДА: 2.4513012944779087
#
# walking_124.csv
#  АМПЛИТУДА: 1.943672266234259
#
# walking_125.csv
#  АМПЛИТУДА: 3.0067304606162786
#
# walking_126.csv
#  АМПЛИТУДА: 1.6664152238883763
#
# walking_13.csv
#  АМПЛИТУДА: 0.15527110513195974
#
# walking_135.csv
#  АМПЛИТУДА: nan
#
# walking_136.csv
#  АМПЛИТУДА: nan
#
# walking_137.csv
#  АМПЛИТУДА: nan
#
# walking_138.csv
#  АМПЛИТУДА: nan
#
# walking_139.csv
#  АМПЛИТУДА: nan
#
# walking_14.csv
#  АМПЛИТУДА: 0.09881917185912625
#
# walking_140.csv
#  АМПЛИТУДА: 1.9430433960735012
#
# walking_141.csv
#  АМПЛИТУДА: 1.795651413928228
#
# walking_142.csv
#  АМПЛИТУДА: 2.0156475471107846
#
# walking_143.csv
#  АМПЛИТУДА: 1.967691289434093
#
# walking_144.csv
#  АМПЛИТУДА: 2.776959468443576
#
# walking_145.csv
#  АМПЛИТУДА: 4.528506362107809
#
# walking_150.csv
#  АМПЛИТУДА: 2.825421667208093
#
# walking_151.csv
#  АМПЛИТУДА: 3.635403332407917
#
# walking_152.csv
#  АМПЛИТУДА: 4.075413881963786
#
# walking_153.csv
#  АМПЛИТУДА: 3.1027674088564674
#
# walking_154.csv
#  АМПЛИТУДА: 1.586041915683281
#
# walking_155.csv
#  АМПЛИТУДА: 1.5983962710381043
#
# walking_156.csv
#  АМПЛИТУДА: 1.71227370497645
#
# walking_157.csv
#  АМПЛИТУДА: 1.6530995997106646
#
# walking_158.csv
#  АМПЛИТУДА: 1.5053228289747225
#
# walking_159.csv
#  АМПЛИТУДА: 1.3577988191448584
#
# walking_160.csv
#  АМПЛИТУДА: 1.7374895292699286
#
# walking_161.csv
#  АМПЛИТУДА: 1.5840190274734898
#
# walking_162.csv
#  АМПЛИТУДА: 1.2454861834751525
#
# walking_163.csv
#  АМПЛИТУДА: 1.1890246043253274
#
# walking_164.csv
#  АМПЛИТУДА: 2.3638808056217098
#
# walking_165.csv
#  АМПЛИТУДА: 3.8452098642281642
#
# walking_166.csv
#  АМПЛИТУДА: 3.8633020284144846
#
# walking_167.csv
#  АМПЛИТУДА: 4.112963437883924
#
# walking_168.csv
#  АМПЛИТУДА: 3.4633351843013633
#
# walking_169.csv
#  АМПЛИТУДА: 3.76068371526513
#
# walking_172.csv
#  АМПЛИТУДА: 5.439104937822687
#
# walking_173.csv
#  АМПЛИТУДА: 3.7398451314272814
#
# walking_174.csv
#  АМПЛИТУДА: 5.303684932132545
#
# walking_175.csv
#  АМПЛИТУДА: 3.8301891290589576
#
# walking_176.csv
#  АМПЛИТУДА: 1.7191375841304284
#
# walking_177.csv
#  АМПЛИТУДА: 2.3968834919449518
#
# walking_178.csv
#  АМПЛИТУДА: 2.8865050973674062
#
# walking_179.csv
#  АМПЛИТУДА: 2.3117741379693837
#
# walking_180.csv
#  АМПЛИТУДА: 2.2451421392033835
#
# walking_181.csv
#  АМПЛИТУДА: 2.732425614488456
#
# walking_182.csv
#  АМПЛИТУДА: 3.4986690699374527
#
# walking_183.csv
#  АМПЛИТУДА: 3.8856115339676958
#
# walking_188.csv
#  АМПЛИТУДА: nan
#
# walking_189.csv
#  АМПЛИТУДА: nan
#
# walking_19.csv
#  АМПЛИТУДА: 2.6428316987311447
#
# walking_190.csv
#  АМПЛИТУДА: nan
#
# walking_191.csv
#  АМПЛИТУДА: 3.58486485826795
#
# walking_192.csv
#  АМПЛИТУДА: 1.6858489176409628
#
# walking_193.csv
#  АМПЛИТУДА: 1.6026682170145816
#
# walking_194.csv
#  АМПЛИТУДА: 1.1894859448658908
#
# walking_195.csv
#  АМПЛИТУДА: 1.393378946273183
#
# walking_20.csv
#  АМПЛИТУДА: 2.1691283052644366
#
# walking_200.csv
#  АМПЛИТУДА: 4.243129456299394
#
# walking_201.csv
#  АМПЛИТУДА: 4.299422213866102
#
# walking_202.csv
#  АМПЛИТУДА: 3.77879553394193
#
# walking_203.csv
#  АМПЛИТУДА: 6.783711185916069
#
# walking_204.csv
#  АМПЛИТУДА: 0.003736848881368493
#
# walking_205.csv
#  АМПЛИТУДА: 2.372130864181978
#
# walking_206.csv
#  АМПЛИТУДА: 2.8820089200252137
#
# walking_207.csv
#  АМПЛИТУДА: 2.3208449350489277
#
# walking_208.csv
#  АМПЛИТУДА: 1.2575892313320316
#
# walking_209.csv
#  АМПЛИТУДА: 1.615846864863366
#
# walking_21.csv
#  АМПЛИТУДА: 1.9185947172702078
#
# walking_210.csv
#  АМПЛИТУДА: 1.475373384796922
#
# walking_211.csv
#  АМПЛИТУДА: 0.8997792480374567
#
# walking_212.csv
#  АМПЛИТУДА: 3.069045386601603
#
# walking_213.csv
#  АМПЛИТУДА: 3.6898885035055393
#
# walking_214.csv
#  АМПЛИТУДА: 3.383683649757121
#
# walking_215.csv
#  АМПЛИТУДА: 1.2188839906196125
#
# walking_22.csv
#  АМПЛИТУДА: 2.446674496643788
#
# walking_220.csv
#  АМПЛИТУДА: 0.07752103505737651
#
# walking_221.csv
#  АМПЛИТУДА: 0.07752103505737651
#
# walking_222.csv
#  АМПЛИТУДА: 0.06506261007654968
#
# walking_223.csv
#  АМПЛИТУДА: 0.06506261007654968
#
# walking_224.csv
#  АМПЛИТУДА: 0.15527110513195974
#
# walking_225.csv
#  АМПЛИТУДА: 0.15527110513195974
#
# walking_226.csv
#  АМПЛИТУДА: 0.09881917185912625
#
# walking_227.csv
#  АМПЛИТУДА: 0.09881917185912625
#
# walking_23.csv
#  АМПЛИТУДА: nan
#
# walking_237.csv
#  АМПЛИТУДА: 1.575707545142796
#
# walking_238.csv
#  АМПЛИТУДА: 1.401932376890709
#
# walking_239.csv
#  АМПЛИТУДА: 1.6843578004986641
#
# walking_24.csv
#  АМПЛИТУДА: 4.254940886853825
#
# walking_240.csv
#  АМПЛИТУДА: 1.4311290794185139
#
# walking_25.csv
#  АМПЛИТУДА: 2.5214082827687596
#
# walking_26.csv
#  АМПЛИТУДА: 1.6255433786007467
#
# walking_27.csv
#  АМПЛИТУДА: 2.268446872472227
#
# walking_28.csv
#  АМПЛИТУДА: 2.353933765759437
#
# walking_32.csv
#  АМПЛИТУДА: 4.4672404658212415
#
# walking_33.csv
#  АМПЛИТУДА: 4.556919843022471
#
# walking_34.csv
#  АМПЛИТУДА: 4.155290313281763
#
# walking_35.csv
#  АМПЛИТУДА: 3.3364159080084295
#
# walking_36.csv
#  АМПЛИТУДА: 4.539651312944863
#
# walking_37.csv
#  АМПЛИТУДА: 2.5600964514006206
#
# walking_38.csv
#  АМПЛИТУДА: 2.5424817445143297
#
# walking_39.csv
#  АМПЛИТУДА: 4.1282917399671275
#
# walking_44.csv
#  АМПЛИТУДА: 7.840666758190602
#
# walking_45.csv
#  АМПЛИТУДА: 8.37059255884173
#
# walking_46.csv
#  АМПЛИТУДА: 8.088834575401997
#
# walking_47.csv
#  АМПЛИТУДА: 8.133729245379595
#
# walking_48.csv
#  АМПЛИТУДА: nan
#
# walking_49.csv
#  АМПЛИТУДА: nan
#
# walking_5.csv
#  АМПЛИТУДА: 1.695833041899772
#
# walking_50.csv
#  АМПЛИТУДА: nan
#
# walking_51.csv
#  АМПЛИТУДА: 1.0870089110987933
#
# walking_52.csv
#  АМПЛИТУДА: 0.9554352093677286
#
# walking_53.csv
#  АМПЛИТУДА: 1.0956610942537526
#
# walking_54.csv
#  АМПЛИТУДА: 1.0836678411923857
#
# walking_55.csv
#  АМПЛИТУДА: 1.200320848949358
#
# walking_56.csv
#  АМПЛИТУДА: 1.2409331302405158
#
# walking_6.csv
#  АМПЛИТУДА: 1.7983896036847562
#
# walking_65.csv
#  АМПЛИТУДА: 2.7327265530157803
#
# walking_66.csv
#  АМПЛИТУДА: 2.888023500919837
#
# walking_67.csv
#  АМПЛИТУДА: 2.8712119772477425
#
# walking_68.csv
#  АМПЛИТУДА: 3.032744844985837
#
# walking_7.csv
#  АМПЛИТУДА: 1.710140089139301
#
# walking_73.csv
#  АМПЛИТУДА: 4.029372775069592
#
# walking_74.csv
#  АМПЛИТУДА: 3.894735017463382
#
# walking_75.csv
#  АМПЛИТУДА: 3.377323322926018
#
# walking_76.csv
#  АМПЛИТУДА: 2.919734412865468
#
# walking_77.csv
#  АМПЛИТУДА: 2.7318475335685037
#
# walking_78.csv
#  АМПЛИТУДА: 3.6400601723344974
#
# walking_79.csv
#  АМПЛИТУДА: 3.39875645655135
#
# walking_8.csv
#  АМПЛИТУДА: 1.928706887664996
#
# walking_80.csv
#  АМПЛИТУДА: 2.9133283090008653
#
# walking_83.csv
#  АМПЛИТУДА: 1.7727690478991724
#
# walking_84.csv
#  АМПЛИТУДА: 1.8523522565163517
#
# walking_85.csv
#  АМПЛИТУДА: 1.1460971875360375
#
# walking_86.csv
#  АМПЛИТУДА: 2.3004233322736356
#
# walking_87.csv
#  АМПЛИТУДА: 2.036037378717901
#
# walking_88.csv
#  АМПЛИТУДА: 1.8154181694664462
#
# walking_89.csv
#  АМПЛИТУДА: nan
#
# walking_9.csv
#  АМПЛИТУДА: 2.2056777531781813
#
# walking_90.csv
#  АМПЛИТУДА: nan
#
# walking_91.csv
#  АМПЛИТУДА: nan
#
# walking_97.csv
#  АМПЛИТУДА: 1.5782438735390873
#
# walking_98.csv
#  АМПЛИТУДА: 1.3625702643131923
#
# walking_99.csv
#  АМПЛИТУДА: 1.192963441369795

# %% [markdown]
# Напишем функцию для получения предсказания (здесь используется только амплитуда, но в вашем итоговом решении будет больше признаков)

# %%
def get_prediction(ampl):
    if ampl < 1:
        return 0 #стояние
    if 1.2 < ampl < 4.8:
        return 1
    if 5 < ampl < 12:
        return 2 #бег
    return 4 #ходьба

# %%
len(Data), len(Ampl), len(Target)
# Out:
# (1135, 1135, 1135)

# %% [markdown]
# Некоторые амплитуды посчитаны некорректно, уберём соответствующие треки.

# %%
good_indices = [i for i in range(len(Ampl)) if not (math.isnan(Ampl[i]) or Ampl[i]==1)]

GoodData   = [Data[i] for i in good_indices]
GoodAmpl   = [Ampl[i] for i in good_indices]
GoodTarget = [Target[i] for i in good_indices]

# %%
len(Data), len(GoodData)
# Out:
# (1135, 1045)

# %% [markdown]
# Создадим таблицу, содержащую номер трека, правильный ответ и предсказание.

# %%
prediction = [get_prediction(a) for a in GoodAmpl]
answer = [get_action(target) for target in GoodTarget]

Res = pd.DataFrame({'track_num' : np.arange(len(GoodData)), 'answer' : answer, 'action' : prediction})
Res.head(10)
# Out:
#    track_num  answer  action
# 0          0       3       1
# 1          1       3       1
# 2          2       3       1
# 3          3       3       2
# 4          4       3       2
# 5          5       3       2
# 6          6       3       2
# 7          7       3       2
# 8          8       3       1
# 9          9       3       1

# %% [markdown]
# Проверим качество нашей модели на тренировочных данных (на данных из открытой папки)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(Res['answer'], Res['action'])
# Out:
# 0.5808612440191387

# %% [markdown]
# В тренировочной папке количество треков разных типов несбалансировано, поэтому для корректной оценки качества нашей модели будем проверять качество модели на таком же распределении треков, как и в тестовой выборке:
#
# * 18% - стояние
# * 18 % - ходьба
# * 18 % - бег
# * 18 % - подъем по лестнице
# * 18 % - велосипед
# * 10% - другие типы движений

# %%
Res['answer'].value_counts(), len(Res)
# Out:
# (1    268
#  0    247
#  2    206
#  4    204
#  3     56
#  5     39
#  7     13
#  6     12
#  Name: answer, dtype: int64,
#  1045)

# %%
import random

ind_0 = random.sample(Res[Res.answer == 0].index.tolist(), 32)
ind_1 = random.sample(Res[Res.answer == 1].index.tolist(), 32)
ind_2 = random.sample(Res[Res.answer == 2].index.tolist(), 32)
ind_3 = random.sample(Res[Res.answer == 3].index.tolist(), 32)
ind_4 = random.sample(Res[Res.answer == 4].index.tolist(), 32)
ind_5 = random.sample(Res[Res.answer == 5].index.tolist(), 6)
ind_6 = random.sample(Res[Res.answer == 6].index.tolist(), 6)
ind_7 = random.sample(Res[Res.answer == 7].index.tolist(), 6)

ind_balanced = ind_0 + ind_1 + ind_2 + ind_3 + ind_4 + ind_5 + ind_6 + ind_7 
len(ind_balanced)
# Out:
# 178

# %%
Res_balanced = Res.iloc[ind_balanced]

# %%
accuracy_score(Res_balanced['answer'], Res_balanced['action'])
# Out:
# 0.48314606741573035
